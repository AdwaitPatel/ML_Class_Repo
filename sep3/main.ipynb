# %% [markdown]
# True postitive = The model correctly predicted the positive class
# True Negative = The model correctly predicted the negative class
# False Positive = The model incorreclty predicted the positive class, when it was negative
# False Negative = The model incorreclty predicted the negative class, when it was positive
#
#
# Q. The model outputs read 3tp, 4tp, 2fp, 1fn. Calcuate the precision.
# Ans.
#
# Q. Calculate the accuracy, precision, recall for F1 score for the following matrix :
#
# | Confusion Matrix | Reality 1   | Reality 0   |
# |---               |---          |---          |
# | Prediction 1     |   75        |    5        |
# | Prediction 0     |    5        |   15        |

# %% [markdown]
# Q.3 Imagine a model trained to classify emails as spam(Positive Class) or not-spam(Negative Class). After testing the model on a dataset of 200 emails, the following results are obtained.
#
# The Actual spam email = 80
# (A) Correclty identified as spam = 60
# (B) Incorreclty identified as spam = 20
#
# Actual not spam email = 120
# (A) Correclty identified as not-spam = 100
# (B) Incorreclty identified as not-spam = 20
#
# Answer the following questions :
# 1. Construct the confusion matrix.
# 2. Compute the accuracy, precision, reacall and F1 score.
#
# Q.4 Predict whether a person is Male or Female based on Height and Weight.
# Training data :
#
# |   Gender  |   Height  |   Weight  |
# |---        |---        |---        |
# |   Male    |   175     |   70      |
# |   Male    |   180     |   80      |
# |   Female  |   160     |   55      |
# |   Female  |   165     |   60      |
#
# New datapoints to classify = Person with [Height = 170cm and Weight = 65kg]
#
# P(Male) = 0.5
# P(Female) = 0.5
#
# Gaussian Probablity Density Function (PDF) :
# $$
# f(x \mid \mu, \sigma^2) = \frac{1}{\sqrt{2 \pi \sigma^2}}
# \exp\left( -\frac{(x - \mu)^2}{2\sigma^2} \right)
# $$

# %% [markdown]
# 3. Classify a person as male or female based on a given dataset using naïve Bayesian  Classifier, and calculate accuracy, precision, and recall for your data set

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, precision_score, recall_score, classification_report
 
# 1. Create a synthetic dataset (replace with your actual dataset)
data = {
   'height_cm': [170, 165, 180, 160, 175, 155, 185, 168],
   'weight_kg': [70, 55, 85, 50, 78, 48, 90, 60],
   'foot_size_cm': [28, 24, 30, 23, 29, 22, 31, 25],
   'gender': ['Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female']
}
df = pd.DataFrame(data)
 
# Convert 'gender' to numerical labels
df['gender'] = df['gender'].map({'Male': 1, 'Female': 0})
 
# Separate features (X) and target (y)
X = df[['height_cm', 'weight_kg', 'foot_size_cm']]
y = df['gender']
 
# print(X)
# print(y) 

# 2. Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
 
# 3. Initialize and train the Naive Bayes Classifier (Gaussian Naive Bayes for continuous data)
model = GaussianNB()
model.fit(X_train, y_train)
 
# 4. Make predictions on the test set
y_pred = model.predict(X_test)
 
# 5. Calculate and print evaluation metrics
print(f"Accuracy: {accuracy_score(y_test, y_pred):.2f}")
print(f"Precision (Male): {precision_score(y_test, y_pred, pos_label=1):.2f}")
print(f"Recall (Male): {recall_score(y_test, y_pred, pos_label=1):.2f}")
 
#6 For a more detailed report including both classes
print("\nClassification Report:")
print(classification_report(y_test, y_pred, target_names=['Female', 'Male']))
 
#7 You can also make a prediction on a new, unseen sample
new_sample = [[160, 48, 21],[180, 55, 30],[140, 46, 28]]
# Example new sample
predicted_class = model.predict(new_sample)
print(f"Predicted class for new sample: {predicted_class:}")
# Out:
#    height_cm  weight_kg  foot_size_cm
# 0        170         70            28
# 1        165         55            24
# 2        180         85            30
# 3        160         50            23
# 4        175         78            29
# 5        155         48            22
# 6        185         90            31
# 7        168         60            25
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# 5    0
# 6    1
# 7    0
# Name: gender, dtype: int64
# Accuracy: 1.00
# Precision (Male): 1.00
# Recall (Male): 1.00
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Female       1.00      1.00      1.00         2
#         Male       1.00      1.00      1.00         1
#
#     accuracy                           1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
# Predicted class for new sample: [0 1 0]
# ...
